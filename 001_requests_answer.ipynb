# %%
#Create an API client
import os
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])
model = "gemini-2.5-flash"

def add_user_message(messages,text):
    user_message = {"role": "user", "parts": [{"text": text}]}
    messages.append(user_message)

def add_assistant_message(messages,text):
    assistant_message = {"role": "model", "parts": [{"text": text}]}
    messages.append(assistant_message)

def chat(messages):
    message = client.models.generate_content(
        model=model,
        contents=messages
    )
    return message.text

# %%
messages = []

#Use a 'while true' loop to run the chatbot forever
while True:
    #Get user input
    user_input = input("> ")
    print(">", user_input)

    #Add user input to the list of messages
    add_user_message(messages, user_input)
    #Call with the 'chat' function
    answer = chat(messages)
    #Add generated text to the list of messages
    add_assistant_message(messages, answer)

    #Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > what's 1+1
# ---
# 1+1 equals 2.
# ---
# > Add 2 more
# ---
# Okay, so if we take the previous result (which was 2) and add 2 more to it:
#
# 2 + 2 = **4**
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 #Use a 'while true' loop to run the chatbot forever
#       4 while True:
#       5     #Get user input
# ----> 6     user_input = input("> ")
#       7     print(">", user_input)
#       8
#       9     #Add user input to the list of messages
#
# File ~/IdeaProjects/JupyterProject/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/IdeaProjects/JupyterProject/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
